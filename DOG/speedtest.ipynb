# %%
import jax
import jax.numpy as jnp
import chex
from dog import *

# %% [markdown]
# ### speed test all validation functions

# %%
env = env_reset(0, distance=jnp.int32(10),
                enable_circular_board=True,
                enable_jump_in_goal_area=True,
                enable_start_blocking=False)
env.pins = jnp.array([[38,40,41,0],
                      [6, 45, 44, -1]])
env.board = set_pins_on_board(env.board, env.pins)
env.current_player = 0

# %%
def test_swap():
    val_swap(env)

def test_normal_move():
    all_moves = jnp.array([1,2,3,4,-4,5,6,8,9,10,11,12,13])
    for move in all_moves:
        val_action_normal_move(env, move)

def test_seven_move():
    for dist in DISTS_7_4:
        val_action_7(env, dist)

# %%
# %timeit -n 1000 test_swap()
# Out:
# 3.09 ms ± 316 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit -n 1000 test_normal_move()
# Out:
# 528 µs ± 143 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit -n 1000 test_seven_move()
# Out:
# 3.74 ms ± 266 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
